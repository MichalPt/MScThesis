# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.insert(1, '../quantarhei')
sys.path.insert(2, '../spectre')
import quantarhei as qr
import spectre
import spectre.full as sef
import spectre.spectroscopy.abs_spectroscopy as abss

# %% [markdown]
# # (1.) - Initial version - step 0.05

# %%
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta-2modes/J-scanopt-ether02-2modes-free/results_J-ether02-2modes-free-144-s005-P_scanopt_01_2023-07-11_08-48-24"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

ref_id = 2
ivalue = 1.2

lim0 = None
lim1 = None

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    #lab = f.split('.')[0].split('_')[2]
    lab = optpars['dipx'][0]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(ref_id, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_21752\4220794966.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 2685.05397189
# Reorg: 35.7824636541
# Reorg: 489.353098264
# Reorg: 118.52171164
# System init: 9.67s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 11.78s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 2744.67706306
# Reorg: 35.6717371931
# Reorg: 476.945543074
# Reorg: 118.870178511
# System init: 10.21s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.16s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2793.18448413
# Reorg: 35.5989667889
# Reorg: 470.7346518
# Reorg: 119.23577495
# System init: 10.09s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.05s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 2801.76827263
# Reorg: 35.5836463512
# Reorg: 469.790891562
# Reorg: 119.343685971
# System init: 10.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.05s
# Spectrum calculation (CPU): 2min 13s
# Reorg: 2817.93334256
# Reorg: 35.5472727758
# Reorg: 468.916803922
# Reorg: 119.541149604
# System init: 10.31s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.33s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 2810.88249059
# Reorg: 35.5312967037
# Reorg: 469.868793091
# Reorg: 119.636611872
# System init: 10.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.16s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2809.7835414
# Reorg: 35.5271230976
# Reorg: 470.231936195
# Reorg: 119.716852564
# System init: 10.15s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.09s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2807.32595192
# Reorg: 35.5205212307
# Reorg: 470.596092407
# Reorg: 119.792907998
# System init: 10.04s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.3min finished
# Tensor calculation: 12.39s
# Spectrum calculation (CPU): 2min 17s
# Reorg: 2817.80112346
# Reorg: 35.5157071133
# Reorg: 470.176370004
# Reorg: 119.848355604
# System init: 10.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 11.92s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2801.74050115
# Reorg: 35.5062321285
# Reorg: 472.866555024
# Reorg: 119.968631676
# System init: 10.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 11.99s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 2728.89341597
# Reorg: 35.4816258211
# Reorg: 481.445955759
# Reorg: 120.002268345
# System init: 10.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.08s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2692.12581804
# Reorg: 35.4721300702
# Reorg: 485.266717239
# Reorg: 120.041124383
# System init: 9.84s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.12s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2625.38591024
# Reorg: 35.4546155434
# Reorg: 492.710368071
# Reorg: 120.045727556
# System init: 11.79s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.1min finished
# Tensor calculation: 12.31s
# Spectrum calculation (CPU): 2min 9s
# Reorg: 2613.9422957
# Reorg: 35.4485810254
# Reorg: 491.109995022
# Reorg: 120.163062966
# System init: 9.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.05s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2588.70754485
# Reorg: 35.4435732468
# Reorg: 493.097152463
# Reorg: 120.129755464
# System init: 10.10s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.08s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2573.817521
# Reorg: 35.3315584186
# Reorg: 473.113108688
# Reorg: 121.191024411
# System init: 10.22s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.26s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 2480.74952198
# Reorg: 35.9033133362
# Reorg: 451.396565002
# Reorg: 122.459059112
# System init: 10.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.17s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 2436.64553498
# Reorg: 29.5528208068
# Reorg: 274.01575602
# Reorg: 126.230931139
# System init: 10.21s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.15s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2436.65546175
# Reorg: 29.5528211873
# Reorg: 274.015805831
# Reorg: 126.230931919
# System init: 10.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.19s
# Spectrum calculation (CPU): 2min 15s
# Reorg: 2436.45989102
# Reorg: 29.5527957199
# Reorg: 274.004136046
# Reorg: 126.230941105
# System init: 10.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.17s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2679.13549001
# Reorg: 30.1211282801
# Reorg: 239.723359642
# Reorg: 120.223747892
# System init: 10.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.11s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 2676.21755912
# Reorg: 30.1334103753
# Reorg: 240.842824758
# Reorg: 120.22658942
# System init: 10.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.10s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 2023.72091984
# Reorg: 28.2751469204
# Reorg: 196.632347626
# Reorg: 133.357616869
# System init: 10.21s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.16s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 1787.25159536
# Reorg: 47.7457241628
# Reorg: 175.70807507
# Reorg: 135.904395197
# System init: 9.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.33s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 1571.48489281
# Reorg: 54.5567677684
# Reorg: 218.069329599
# Reorg: 137.651523792
# System init: 10.14s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.10s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 1485.2285913
# Reorg: 127.862696153
# Reorg: 187.54135655
# Reorg: 137.24188684
# System init: 10.13s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.08s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 1397.23133995
# Reorg: 254.245661903
# Reorg: 182.612534992
# Reorg: 138.265668317
# System init: 10.17s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.10s
# Spectrum calculation (CPU): 2min 13s
# Reorg: 1310.66655851
# Reorg: 394.668673708
# Reorg: 180.189338957
# Reorg: 139.852059648
# System init: 9.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.12s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 1155.83591396
# Reorg: 665.207009871
# Reorg: 241.198971291
# Reorg: 143.427207649
# System init: 10.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.27s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 1057.37078729
# Reorg: 778.316816908
# Reorg: 255.084859772
# Reorg: 144.86876524
# System init: 11.73s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.27s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 966.026299718
# Reorg: 820.398985511
# Reorg: 255.274989973
# Reorg: 145.975294969
# System init: 9.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.13s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 914.123060485
# Reorg: 887.971537459
# Reorg: 249.562586772
# Reorg: 146.057799383
# System init: 9.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.37s
# Spectrum calculation (CPU): 2min 12s
# Reorg: 877.91898959
# Reorg: 1187.46834971
# Reorg: 248.19517239
# Reorg: 146.557024236
# System init: 10.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.10s
# Spectrum calculation (CPU): 2min 10s
# Reorg: 843.713976354
# Reorg: 1395.99890108
# Reorg: 250.18794295
# Reorg: 146.819774052
# System init: 9.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.22s
# Spectrum calculation (CPU): 2min 11s
# Reorg: 815.978461728
# Reorg: 1599.44777329
# Reorg: 251.79238651
# Reorg: 147.749922823
# System init: 10.15s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.2min finished
# Tensor calculation: 12.27s
# Spectrum calculation (CPU): 2min 11s
# C:\Users\micha\AppData\Local\Temp\ipykernel_21752\4220794966.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(ref_id, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)[:,lim0:lim1]

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        #lab = f.split('.')[0].split('_')[2]
        lab = optpars['dipx'][0]
        
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(ref_id, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'dipx []')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering dipx []}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_21752\3489226299.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_21752\3489226299.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 52.62it/s]
# 0.0377167885671
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()
ang = list()

for i, f in enumerate(sfiles[lim0:lim1]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    #lab = f.split('.')[0].split('_')[2]
    lab = optpars['dipx'][0]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])
    ang.append(optpars['angle'])

ii = [i for i,x in enumerate(labels) if x == ivalue][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

# ## omega
# grid[3,1].plot(labels, om1, **pars)
# grid[3,1].plot(labels[ii], om1[ii], **mpars)
# grid[3,1].set_title('OM1')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## dE
# grid[3,1].plot(labels, de, **pars)
# grid[3,1].plot(labels[ii], de[ii], **mpars)
# grid[3,1].set_title('dE')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

## angle
grid[3,1].plot(labels, ang, **pars)
grid[3,1].plot(labels[ii], ang[ii], **mpars)
grid[3,1].set_title('angle')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    

grid[0,0].set_ylim(0,310)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.11)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

grid[0,0].set_xlim(0, 2)
grid[0,2].set_ylim(0,90)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(0.5))
    g.xaxis.set_major_formatter('{x:.1f}')
    g.xaxis.set_minor_locator(MultipleLocator(0.25))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('dipx []')

grid[3,1].ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=False)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_21752\1161401853.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))

# %% [markdown]
# # (2.) - Finer step - step 0.02

# %%
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta/J-scanopt-pyr06-1mode/results_J-pyr06-1mode-s002-P-177_scanopt_01_2023-07-13_02-16-42"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

ref_id = 6
ivalue = 1.0

lim0 = None
lim1 = None

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(ref_id, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_46904\4220794966.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 2273.38841347
# Reorg: 180.575205952
# System init: 5.35s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.2s finished
# Tensor calculation: 1.15s
# Spectrum calculation (CPU): 5.39s
# Reorg: 2273.38841347
# Reorg: 180.575205952
# System init: 4.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.3s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.49s
# Reorg: 2279.17772751
# Reorg: 180.86734096
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.90s
# Reorg: 2281.83546403
# Reorg: 180.67691035
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.11s
# Spectrum calculation (CPU): 4.89s
# Reorg: 2279.54409012
# Reorg: 180.359579342
# System init: 5.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.82s
# Reorg: 2309.28730285
# Reorg: 178.040772332
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 5.00s
# Reorg: 2308.42213904
# Reorg: 177.772240064
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.10s
# Spectrum calculation (CPU): 4.87s
# Reorg: 2308.51750874
# Reorg: 177.635333767
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.75s
# Reorg: 2310.70107893
# Reorg: 176.850883962
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.2s finished
# Tensor calculation: 1.14s
# Spectrum calculation (CPU): 4.42s
# Reorg: 2307.9872008
# Reorg: 176.190534253
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.0s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.21s
# Reorg: 2309.54214794
# Reorg: 175.745777165
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.91s
# Reorg: 2306.54776879
# Reorg: 174.800748332
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 5.16s
# Reorg: 2301.14124178
# Reorg: 174.74098156
# System init: 5.05s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.83s
# Reorg: 2300.47516908
# Reorg: 174.368754843
# System init: 5.10s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.3s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.48s
# Reorg: 2297.12194727
# Reorg: 173.358028364
# System init: 5.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.18s
# Spectrum calculation (CPU): 4.67s
# Reorg: 2295.22797347
# Reorg: 172.989285753
# System init: 5.17s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.15s
# Spectrum calculation (CPU): 4.62s
# Reorg: 2293.17082496
# Reorg: 172.708443585
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.15s
# Spectrum calculation (CPU): 4.61s
# Reorg: 2291.70824071
# Reorg: 172.543741478
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.1s finished
# Tensor calculation: 1.22s
# Spectrum calculation (CPU): 4.33s
# Reorg: 2238.85273373
# Reorg: 123.876981819
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.09s
# Spectrum calculation (CPU): 4.59s
# Reorg: 2237.18637817
# Reorg: 123.749725121
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.2s finished
# Tensor calculation: 1.11s
# Spectrum calculation (CPU): 4.45s
# Reorg: 2204.29906499
# Reorg: 121.241074538
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.69s
# Reorg: 2200.62714215
# Reorg: 121.080813334
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.64s
# Reorg: 2153.38289131
# Reorg: 57.7480803872
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.2s finished
# Tensor calculation: 1.11s
# Spectrum calculation (CPU): 4.45s
# Reorg: 2184.223252
# Reorg: 57.6967269547
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.11s
# Spectrum calculation (CPU): 4.69s
# Reorg: 2131.29571662
# Reorg: 88.9049535343
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.11s
# Spectrum calculation (CPU): 4.68s
# Reorg: 2127.29622533
# Reorg: 88.9035679689
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.1s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.31s
# Reorg: 2126.7367114
# Reorg: 88.9036502585
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.0s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.20s
# Reorg: 2126.61489313
# Reorg: 88.9035905394
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.1s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.34s
# Reorg: 2126.61475878
# Reorg: 88.9035882351
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.80s
# Reorg: 2128.72140993
# Reorg: 89.0551019403
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.90s
# Reorg: 2128.72140993
# Reorg: 89.0551019403
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.3s finished
# Tensor calculation: 1.12s
# Spectrum calculation (CPU): 4.49s
# Reorg: 2128.72140993
# Reorg: 89.0551019403
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.3s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 4.49s
# Reorg: 2128.64642535
# Reorg: 89.0551200184
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.13s
# Spectrum calculation (CPU): 5.06s
# Reorg: 2128.64384642
# Reorg: 89.0551185212
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.16s
# Spectrum calculation (CPU): 4.69s
# Reorg: 2125.68529891
# Reorg: 91.422834625
# System init: 5.25s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.21s
# Spectrum calculation (CPU): 4.83s
# Reorg: 2125.50570922
# Reorg: 91.422882837
# System init: 5.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 4.80s
# Reorg: 2125.47563424
# Reorg: 91.4228895183
# System init: 6.15s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.24s
# Spectrum calculation (CPU): 4.73s
# Reorg: 2125.40755475
# Reorg: 91.4228927491
# System init: 5.65s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.1s finished
# Tensor calculation: 1.52s
# Spectrum calculation (CPU): 5.35s
# Reorg: 2088.08097252
# Reorg: 93.2607222102
# System init: 5.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.34s
# Spectrum calculation (CPU): 4.92s
# Reorg: 2088.05536335
# Reorg: 93.2607276114
# System init: 6.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.31s
# Spectrum calculation (CPU): 4.77s
# Reorg: 2088.05536335
# Reorg: 93.2607276114
# System init: 6.43s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 5.04s
# Reorg: 2088.05536335
# Reorg: 93.2607276114
# System init: 5.57s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.46s
# Spectrum calculation (CPU): 5.15s
# Reorg: 2088.05536335
# Reorg: 93.2607276114
# System init: 5.54s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 4.99s
# Reorg: 2049.20508818
# Reorg: 97.9194009727
# System init: 6.45s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.35s
# Spectrum calculation (CPU): 4.97s
# Reorg: 1998.51557351
# Reorg: 106.179023681
# System init: 5.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.25s
# Spectrum calculation (CPU): 4.89s
# Reorg: 1998.51377101
# Reorg: 106.179029731
# System init: 5.48s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.2s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 5.46s
# Reorg: 1984.12185971
# Reorg: 120.568223491
# System init: 5.80s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.25s
# Spectrum calculation (CPU): 5.06s
# Reorg: 1978.86781233
# Reorg: 120.623429544
# System init: 6.21s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.36s
# Spectrum calculation (CPU): 5.00s
# Reorg: 1975.25653704
# Reorg: 120.624802706
# System init: 6.05s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.28s
# Spectrum calculation (CPU): 4.89s
# Reorg: 1969.4712757
# Reorg: 120.621749633
# System init: 5.53s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.2s finished
# Tensor calculation: 1.44s
# Spectrum calculation (CPU): 5.43s
# Reorg: 1986.97063052
# Reorg: 120.099586397
# System init: 6.08s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.36s
# Spectrum calculation (CPU): 5.00s
# Reorg: 1984.46575288
# Reorg: 120.097098432
# System init: 6.31s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.33s
# Spectrum calculation (CPU): 5.05s
# Reorg: 1990.35140364
# Reorg: 109.157853791
# System init: 6.41s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.20s
# Spectrum calculation (CPU): 5.04s
# Reorg: 1991.50033044
# Reorg: 109.446167261
# System init: 5.79s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.3s finished
# Tensor calculation: 1.48s
# Spectrum calculation (CPU): 5.55s
# Reorg: 1989.55955939
# Reorg: 109.451485952
# System init: 5.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.33s
# Spectrum calculation (CPU): 5.06s
# Reorg: 1986.04315502
# Reorg: 110.804359236
# System init: 5.74s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.37s
# Spectrum calculation (CPU): 5.10s
# Reorg: 1982.6517089
# Reorg: 110.821310962
# System init: 6.34s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.19s
# Spectrum calculation (CPU): 4.76s
# Reorg: 1977.09257103
# Reorg: 111.020594106
# System init: 5.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.2s finished
# Tensor calculation: 1.61s
# Spectrum calculation (CPU): 5.36s
# Reorg: 1889.50163657
# Reorg: 855.015359345
# System init: 5.57s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.19s
# Spectrum calculation (CPU): 5.10s
# Reorg: 1873.06558303
# Reorg: 862.299285416
# System init: 5.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 4.88s
# Reorg: 1870.01851106
# Reorg: 854.159933107
# System init: 6.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.21s
# Spectrum calculation (CPU): 4.62s
# Reorg: 1846.50251889
# Reorg: 873.901405659
# System init: 5.65s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.4s finished
# Tensor calculation: 1.54s
# Spectrum calculation (CPU): 5.65s
# Reorg: 1833.44686272
# Reorg: 891.75067865
# System init: 5.63s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 5.04s
# Reorg: 1804.93486491
# Reorg: 886.251464176
# System init: 5.76s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 4.98s
# Reorg: 1795.8986756
# Reorg: 912.738499544
# System init: 6.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 4.89s
# Reorg: 1780.49876228
# Reorg: 915.267731914
# System init: 5.75s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.5s finished
# Tensor calculation: 1.73s
# Spectrum calculation (CPU): 5.76s
# Reorg: 1766.66737136
# Reorg: 916.733497688
# System init: 5.61s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 4.97s
# Reorg: 1760.179997
# Reorg: 883.356205079
# System init: 5.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 4.63s
# Reorg: 1727.38919829
# Reorg: 941.526607197
# System init: 6.30s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.26s
# Spectrum calculation (CPU): 4.83s
# Reorg: 1697.51892434
# Reorg: 969.438021297
# System init: 5.85s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.2s finished
# Tensor calculation: 1.71s
# Spectrum calculation (CPU): 5.45s
# Reorg: 1657.37151797
# Reorg: 997.422200901
# System init: 5.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.22s
# Spectrum calculation (CPU): 5.08s
# Reorg: 1633.35756908
# Reorg: 1002.74010784
# System init: 5.81s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.34s
# Spectrum calculation (CPU): 4.70s
# Reorg: 1619.58978392
# Reorg: 1004.50696055
# System init: 6.35s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.19s
# Spectrum calculation (CPU): 4.90s
# Reorg: 1582.91713382
# Reorg: 1028.13287605
# System init: 5.69s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.1s finished
# Tensor calculation: 1.85s
# Spectrum calculation (CPU): 5.36s
# Reorg: 1542.3482619
# Reorg: 1024.22226085
# System init: 5.79s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.25s
# Spectrum calculation (CPU): 5.02s
# Reorg: 1496.13319053
# Reorg: 1085.83082144
# System init: 5.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 4.81s
# Reorg: 1469.31779246
# Reorg: 1124.65409612
# System init: 6.30s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.31s
# Spectrum calculation (CPU): 4.74s
# Reorg: 1435.00744726
# Reorg: 1065.12432977
# System init: 5.71s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.1s finished
# Tensor calculation: 1.87s
# Spectrum calculation (CPU): 5.33s
# Reorg: 1441.18011687
# Reorg: 1111.13236006
# System init: 5.80s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.0s finished
# Tensor calculation: 1.24s
# Spectrum calculation (CPU): 5.19s
# Reorg: 1420.81242655
# Reorg: 1137.88843082
# System init: 5.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.6s finished
# Tensor calculation: 1.24s
# Spectrum calculation (CPU): 4.82s
# Reorg: 1389.51685883
# Reorg: 1130.09576987
# System init: 6.54s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.19s
# Spectrum calculation (CPU): 4.73s
# Reorg: 1369.1242419
# Reorg: 1151.14240092
# System init: 6.11s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.4s finished
# Tensor calculation: 1.71s
# Spectrum calculation (CPU): 4.58s
# Reorg: 1350.21426042
# Reorg: 1152.37747145
# System init: 5.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 4.99s
# Reorg: 1345.49825405
# Reorg: 1115.10764596
# System init: 5.80s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.34s
# Spectrum calculation (CPU): 4.67s
# Reorg: 1302.97425083
# Reorg: 1193.93117568
# System init: 6.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 4.71s
# Reorg: 1228.37297126
# Reorg: 1303.32140086
# System init: 5.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.4s finished
# Tensor calculation: 1.67s
# Spectrum calculation (CPU): 5.63s
# Reorg: 1203.48857299
# Reorg: 1276.62570157
# System init: 5.73s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.30s
# Spectrum calculation (CPU): 5.00s
# Reorg: 1220.51623551
# Reorg: 1195.77008868
# System init: 6.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.37s
# Spectrum calculation (CPU): 4.72s
# Reorg: 1206.91039432
# Reorg: 1265.34283643
# System init: 6.28s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 4.88s
# Reorg: 1198.57845329
# Reorg: 1231.67897234
# System init: 5.52s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.3s finished
# Tensor calculation: 1.65s
# Spectrum calculation (CPU): 5.53s
# Reorg: 1173.71358741
# Reorg: 1271.06570989
# System init: 5.68s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 5.01s
# Reorg: 1148.54607757
# Reorg: 1315.66242361
# System init: 5.79s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.27s
# Spectrum calculation (CPU): 4.90s
# Reorg: 1142.68912928
# Reorg: 1336.70489759
# System init: 6.50s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.32s
# Spectrum calculation (CPU): 4.89s
# Reorg: 844.147561563
# Reorg: 2543.73668914
# System init: 5.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.84s
# Spectrum calculation (CPU): 5.06s
# Reorg: 761.765166694
# Reorg: 2808.93269737
# System init: 5.56s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.9s finished
# Tensor calculation: 1.29s
# Spectrum calculation (CPU): 5.09s
# Reorg: 755.413289125
# Reorg: 2813.84661288
# System init: 5.74s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# Tensor calculation: 1.21s
# Spectrum calculation (CPU): 4.75s
# Reorg: 763.96966843
# Reorg: 2784.80800318
# System init: 6.41s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.7s finished
# Tensor calculation: 1.16s
# Spectrum calculation (CPU): 4.89s
# Reorg: 756.658449161
# Reorg: 2790.98819953
# System init: 5.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    5.0s finished
# Tensor calculation: 1.87s
# Spectrum calculation (CPU): 5.22s
# Reorg: 754.304537423
# Reorg: 2779.38265648
# System init: 5.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.8s finished
# Tensor calculation: 1.32s
# Spectrum calculation (CPU): 5.03s
# Reorg: 757.269036624
# Reorg: 2787.7773454
# System init: 5.47s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    4.5s finished
# C:\Users\micha\AppData\Local\Temp\ipykernel_46904\4220794966.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')
# Tensor calculation: 1.37s
# Spectrum calculation (CPU): 4.76s

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(ref_id, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)[:,lim0:lim1]

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        #lab = f.split('.')[0].split('_')[2]
        lab = optpars['dipx'][0]
        
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(ref_id, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'dipx []')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering dipx []}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_46904\3489226299.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_46904\3489226299.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
# 100%|███████████████████████████████████████████████████████████████████████████████████| 100/100 [00:17<00:00,  5.74it/s]
# 0.045449797543
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()
ang = list()

for i, f in enumerate(sfiles[lim0:lim1]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    #lab = f.split('.')[0].split('_')[2]
    lab = optpars['dipx'][0]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])
    ang.append(optpars['angle'])

ii = [i for i,x in enumerate(labels) if x == ivalue][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

# ## omega
# grid[3,1].plot(labels, om1, **pars)
# grid[3,1].plot(labels[ii], om1[ii], **mpars)
# grid[3,1].set_title('OM1')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## dE
# grid[3,1].plot(labels, de, **pars)
# grid[3,1].plot(labels[ii], de[ii], **mpars)
# grid[3,1].set_title('dE')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

## angle
grid[3,1].plot(labels, ang, **pars)
grid[3,1].plot(labels[ii], ang[ii], **mpars)
grid[3,1].set_title('angle')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    

grid[0,0].set_ylim(0,310)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.11)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

grid[0,0].set_xlim(0, 2)
grid[0,2].set_ylim(0,90)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(0.5))
    g.xaxis.set_major_formatter('{x:.1f}')
    g.xaxis.set_minor_locator(MultipleLocator(0.25))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('dipx []')

grid[3,1].ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=False)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_46904\1161401853.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
