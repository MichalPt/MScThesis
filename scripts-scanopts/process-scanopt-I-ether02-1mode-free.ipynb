# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.insert(1, '../quantarhei')
sys.path.insert(2, '../spectre')
import quantarhei as qr
import spectre
import spectre.full as sef
import spectre.spectroscopy.abs_spectroscopy as abss

# %%
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta/I-scanopt-ether02-1mode-free/results_I-ether02-1mode-free-s2-P-11010_scanopt_01_2023-07-10_12-10-11"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

ref_id = 2
ivalue = 70

lim0 = 0
lim1 = None

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(ref_id, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_7452\4220794966.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 2040.00097699
# Reorg: 944.070867557
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.71s
# Reorg: 2039.99416539
# Reorg: 944.070855775
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.33s
# Reorg: 1509.61194708
# Reorg: 806.321955569
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.18s
# Reorg: 2024.59667045
# Reorg: 2558.51486537
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.27s
# Reorg: 2024.59667045
# Reorg: 2558.51486537
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.33s
# Reorg: 1640.4140435
# Reorg: 2272.00403061
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.30s
# Reorg: 1633.96580506
# Reorg: 2272.9986502
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.28s
# Reorg: 2117.36687897
# Reorg: 2455.02613728
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.19s
# Reorg: 1445.10285917
# Reorg: 1906.44069548
# System init: 5.08s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.69s
# Reorg: 1497.75016236
# Reorg: 1997.40614436
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.32s
# Reorg: 3589.82929857
# Reorg: 2068.1887334
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.38s
# Reorg: 1528.07153822
# Reorg: 616.391680249
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.47s
# Reorg: 1500.3724691
# Reorg: 453.529808838
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.88s
# Reorg: 1639.18087928
# Reorg: 456.5337046
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.40s
# Reorg: 1636.17267795
# Reorg: 456.614216902
# System init: 5.11s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.48s
# Reorg: 1501.23648575
# Reorg: 446.362077976
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 8.17s
# Reorg: 1840.5667574
# Reorg: 549.783502534
# System init: 5.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.78s
# Reorg: 1475.54594551
# Reorg: 541.390282194
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.72s
# Reorg: 1475.82706663
# Reorg: 539.62350554
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.80s
# Reorg: 1786.02161055
# Reorg: 368.912653964
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.62s
# Reorg: 1722.7730252
# Reorg: 368.198710245
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 6.95s
# Reorg: 1486.26487484
# Reorg: 337.966595438
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.67s
# Reorg: 1908.30499619
# Reorg: 483.983454254
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.55s
# Reorg: 1918.44585316
# Reorg: 484.248741953
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.46s
# Reorg: 1497.1488969
# Reorg: 434.851189989
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.53s
# Reorg: 1824.87125327
# Reorg: 353.514475272
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.42s
# Reorg: 2182.18203892
# Reorg: 252.57672261
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.53s
# Reorg: 1393.30801014
# Reorg: 185.41452645
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.50s
# Reorg: 2089.29853947
# Reorg: 393.857709032
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.58s
# Reorg: 2098.25334054
# Reorg: 393.856000358
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 7.36s
# Reorg: 1168.72470094
# Reorg: 30.7637432295
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.39s
# Reorg: 1866.90961691
# Reorg: 300.657600241
# System init: 5.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.50s
# Reorg: 1878.28743192
# Reorg: 300.664184099
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.54s
# Reorg: 1334.19800132
# Reorg: 147.273080819
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.41s
# Reorg: 1331.71722383
# Reorg: 147.009758017
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.35s
# Spectrum calculation (CPU): 6.87s
# Reorg: 1331.31501453
# Reorg: 147.217097836
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.1s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 6.28s
# Reorg: 862.489878132
# Reorg: 29.0351760292
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.1s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 6.36s
# Reorg: 1079.02370243
# Reorg: 29.4200478743
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.2s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 6.42s
# Reorg: 1919.30149821
# Reorg: 307.456936297
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.25s
# Reorg: 1577.73376746
# Reorg: 315.567128043
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.46s
# Reorg: 1407.03900203
# Reorg: 109.912873979
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.3s finished
# Tensor calculation: 2.36s
# Spectrum calculation (CPU): 6.47s
# Reorg: 1977.60121409
# Reorg: 130.872958741
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.1s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 6.32s
# Reorg: 1917.60871054
# Reorg: 80.0959405568
# System init: 4.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 8.01s
# Reorg: 1461.43527442
# Reorg: 185.231303525
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.63s
# Reorg: 1635.27856436
# Reorg: 193.810061375
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# C:\Users\micha\AppData\Local\Temp\ipykernel_7452\4220794966.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.57s

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(ref_id, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)[:,lim0:lim1]

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        lab = f.split('.')[0].split('_')[2]
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(ref_id, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'angle [deg]')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering angle [deg]}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_7452\3368266695.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_7452\3368266695.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
# 0.0754487664393
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()
ang = list()

for i, f in enumerate(sfiles[lim0:lim1]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])
    ang.append(optpars['angle'])

ii = [i for i,x in enumerate(labels) if x == ivalue][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

# ## omega
# grid[3,1].plot(labels, om1, **pars)
# grid[3,1].plot(labels[ii], om1[ii], **mpars)
# grid[3,1].set_title('OM1')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## dE
# grid[3,1].plot(labels, de, **pars)
# grid[3,1].plot(labels[ii], de[ii], **mpars)
# grid[3,1].set_title('dE')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

## angle
grid[3,1].plot(labels, ang, **pars)
grid[3,1].plot(labels[ii], ang[ii], **mpars)
grid[3,1].set_title('angle')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    

grid[0,0].set_ylim(0,310)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.11)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

#grid[0,0].set_xlim(10, 80)
grid[0,2].set_ylim(0,90)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(30))
    g.xaxis.set_major_formatter('{x:.0f}')
    g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('angle [deg]')

grid[3,1].ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=False)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_7452\836227060.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))

# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.insert(1, '../quantarhei')
sys.path.insert(2, '../spectre')
import quantarhei as qr
import spectre
import spectre.full as sef
import spectre.spectroscopy.abs_spectroscopy as abss

# %% [markdown]
# # (2.) step 1

# %%
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta/I-scanopt-ether02-1mode-free/results_I-ether02-1mode-free-s1-P-11010_scanopt_01_2023-07-13_02-19-10"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

ref_id = 2
ivalue = 70

lim0 = 0
lim1 = None

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(ref_id, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_29144\4220794966.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 1563.36503334
# Reorg: 840.427254294
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.91s
# Reorg: 1756.9239781
# Reorg: 1116.26331042
# System init: 4.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.15s
# Reorg: 1745.0302987
# Reorg: 1218.27585896
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.34s
# Reorg: 1745.0302987
# Reorg: 1218.27585896
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.35s
# Spectrum calculation (CPU): 7.12s
# Reorg: 1595.06946609
# Reorg: 962.969641903
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.02s
# Reorg: 1519.77401195
# Reorg: 543.714924622
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.17s
# Reorg: 1512.83906132
# Reorg: 744.566112431
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.11s
# Reorg: 1795.2021157
# Reorg: 839.418950802
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.33s
# Reorg: 2221.87376331
# Reorg: 1558.96653566
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 7.35s
# Reorg: 2194.10341365
# Reorg: 1544.10061236
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.21s
# Reorg: 1692.70756919
# Reorg: 1130.27597606
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.52s
# Reorg: 1512.2557263
# Reorg: 724.281695146
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.22s
# Reorg: 1514.17526014
# Reorg: 685.775179253
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.34s
# Spectrum calculation (CPU): 7.30s
# Reorg: 1667.34167755
# Reorg: 1328.84058615
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.22s
# Reorg: 2155.49729962
# Reorg: 1303.90635347
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.20s
# Reorg: 2104.69019025
# Reorg: 827.007714889
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 6.94s
# Reorg: 1590.47722579
# Reorg: 778.614785046
# System init: 5.16s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.03s
# Reorg: 1520.83864895
# Reorg: 744.602015516
# System init: 4.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.21s
# Reorg: 1514.38124777
# Reorg: 703.430797475
# System init: 4.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.13s
# Reorg: 1593.867874
# Reorg: 1285.66783164
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.08s
# Reorg: 1631.34603661
# Reorg: 1628.78029799
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 6.90s
# Reorg: 1631.34603661
# Reorg: 1628.78029799
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 6.88s
# Reorg: 1631.32842492
# Reorg: 1628.78172016
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 6.90s
# Reorg: 1568.09326786
# Reorg: 1592.96805025
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.07s
# Reorg: 1450.29348678
# Reorg: 2274.16693146
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 7.10s
# Reorg: 1374.40290638
# Reorg: 2270.68685671
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.19s
# Reorg: 1373.01854167
# Reorg: 2269.58030029
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.00s
# Reorg: 1384.5524924
# Reorg: 2268.32476623
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.08s
# Reorg: 1384.55050972
# Reorg: 2268.32465319
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.33s
# Spectrum calculation (CPU): 7.04s
# Reorg: 1384.38798783
# Reorg: 2268.31107037
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.32s
# Reorg: 1393.21192531
# Reorg: 2264.17014274
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.28s
# Reorg: 1393.66516729
# Reorg: 2264.17440744
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.25s
# Reorg: 1393.66693317
# Reorg: 2264.17600592
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.20s
# Reorg: 1401.10710475
# Reorg: 2264.29117555
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.15s
# Reorg: 1409.69414752
# Reorg: 2263.83110075
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.32s
# Reorg: 1417.21426898
# Reorg: 2257.82682599
# System init: 4.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.35s
# Reorg: 1517.81163878
# Reorg: 2257.45022153
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.23s
# Reorg: 1782.33595811
# Reorg: 2205.41318504
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.31s
# Reorg: 2347.58737719
# Reorg: 2066.05748869
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.13s
# Reorg: 2347.57183971
# Reorg: 2066.07979119
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.34s
# Spectrum calculation (CPU): 7.06s
# Reorg: 2263.73556521
# Reorg: 1983.4550238
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.39s
# Spectrum calculation (CPU): 7.15s
# Reorg: 1528.58410991
# Reorg: 1623.88667938
# System init: 4.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 7.16s
# Reorg: 1570.93757581
# Reorg: 1620.5922892
# System init: 4.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.32s
# Reorg: 1523.61467418
# Reorg: 1683.6553105
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.28s
# Reorg: 1523.61405652
# Reorg: 1683.6553086
# System init: 5.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.33s
# Spectrum calculation (CPU): 7.37s
# Reorg: 2028.8755745
# Reorg: 1575.14577892
# System init: 4.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.07s
# Reorg: 1804.51436823
# Reorg: 1477.00628598
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.09s
# Reorg: 1540.04809411
# Reorg: 1094.34940637
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.25s
# Reorg: 1582.18404952
# Reorg: 1066.70541579
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 6.96s
# Reorg: 1522.26586291
# Reorg: 885.405468673
# System init: 4.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 6.93s
# Reorg: 1522.26531583
# Reorg: 885.405463529
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.07s
# Reorg: 1964.43448374
# Reorg: 1537.50085379
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.22s
# Spectrum calculation (CPU): 7.26s
# Reorg: 1969.87191454
# Reorg: 1941.26931159
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.18s
# Reorg: 1849.27636544
# Reorg: 1635.94423446
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.10s
# Reorg: 1685.97082761
# Reorg: 1157.78719666
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.53s
# Reorg: 1542.07251925
# Reorg: 509.674877048
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 6.99s
# Reorg: 1511.69691071
# Reorg: 516.620448065
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.16s
# Reorg: 1645.99963045
# Reorg: 1105.77284963
# System init: 5.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.08s
# Reorg: 1541.80667978
# Reorg: 548.43979348
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.12s
# Reorg: 1541.80667978
# Reorg: 548.43979348
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.15s
# Reorg: 1529.8642273
# Reorg: 550.443944533
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.21s
# Reorg: 1502.36070517
# Reorg: 495.465851448
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.19s
# Reorg: 1507.34686533
# Reorg: 397.521500452
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.30s
# Reorg: 1537.14638175
# Reorg: 632.746455588
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.02s
# Reorg: 1545.18141844
# Reorg: 533.423951569
# System init: 5.28s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.6s finished
# Tensor calculation: 2.36s
# Spectrum calculation (CPU): 6.83s
# Reorg: 1545.18141844
# Reorg: 533.423951569
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 6.99s
# Reorg: 1545.15846338
# Reorg: 533.42297978
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.08s
# Reorg: 1526.51951496
# Reorg: 524.891986445
# System init: 4.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.12s
# Reorg: 1442.39928859
# Reorg: 33.224510897
# System init: 4.84s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.62s
# Reorg: 1331.71722383
# Reorg: 147.009758017
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.52s
# Spectrum calculation (CPU): 7.28s
# Reorg: 1139.49366109
# Reorg: 170.959268556
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.17s
# Reorg: 967.285952756
# Reorg: 549.137957816
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.08s
# Reorg: 1081.44488833
# Reorg: 536.194292472
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.38s
# Reorg: 1081.50180003
# Reorg: 536.19258352
# System init: 4.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.14s
# Reorg: 1094.94946835
# Reorg: 535.698091527
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.16s
# Reorg: 1094.73507531
# Reorg: 535.704690144
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.32s
# Reorg: 1096.78943703
# Reorg: 533.923290448
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.03s
# Reorg: 1056.07880623
# Reorg: 548.347641098
# System init: 5.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.34s
# Spectrum calculation (CPU): 7.22s
# Reorg: 1058.04302095
# Reorg: 548.305307066
# System init: 5.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.19s
# Reorg: 1057.42595721
# Reorg: 548.312891511
# System init: 5.11s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.18s
# Reorg: 1057.41205106
# Reorg: 548.317148655
# System init: 5.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.98s
# Reorg: 1057.41424332
# Reorg: 548.317273653
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.76s
# Reorg: 1069.22505059
# Reorg: 548.014483037
# System init: 4.85s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.71s
# Reorg: 1057.13673266
# Reorg: 547.635787176
# System init: 4.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.85s
# Reorg: 1046.13835755
# Reorg: 578.322415131
# System init: 4.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.82s
# Reorg: 1081.85703575
# Reorg: 570.165112972
# System init: 5.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.21s
# Reorg: 1409.74568984
# Reorg: 99.7903893465
# System init: 5.18s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.13s
# Reorg: 1394.70002045
# Reorg: 99.8048866422
# System init: 5.10s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.37s
# Reorg: 1394.986195
# Reorg: 99.8045427074
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.14s
# Reorg: 1353.58194514
# Reorg: 174.512131708
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# C:\Users\micha\AppData\Local\Temp\ipykernel_29144\4220794966.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.14s

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(ref_id, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)[:,lim0:lim1]

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        lab = f.split('.')[0].split('_')[2]
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [ivalue,ivalue], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(ref_id, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'angle [deg]')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering angle [deg]}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_29144\3368266695.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_29144\3368266695.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
#  32%|███████████████████████████▍                                                         | 29/90 [00:42<01:14,  1.22s/it]C:\Users\micha\miniconda3\envs\py310-maya-1\lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 90/90 [02:06<00:00,  1.40s/it]
# 0.117246475368
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()
ang = list()

for i, f in enumerate(sfiles[lim0:lim1]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])
    ang.append(optpars['angle'])

ii = [i for i,x in enumerate(labels) if x == ivalue][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

# ## omega
# grid[3,1].plot(labels, om1, **pars)
# grid[3,1].plot(labels[ii], om1[ii], **mpars)
# grid[3,1].set_title('OM1')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## dE
# grid[3,1].plot(labels, de, **pars)
# grid[3,1].plot(labels[ii], de[ii], **mpars)
# grid[3,1].set_title('dE')
# #draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

## angle
grid[3,1].plot(labels, ang, **pars)
grid[3,1].plot(labels[ii], ang[ii], **mpars)
grid[3,1].set_title('angle')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    

grid[0,0].set_ylim(0,310)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.11)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

#grid[0,0].set_xlim(10, 80)
grid[0,2].set_ylim(0,90)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(30))
    g.xaxis.set_major_formatter('{x:.0f}')
    g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('angle [deg]')

grid[3,1].ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=False)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_29144\836227060.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
