# %%
import numpy as np
from matplotlib import pyplot as plt
import sys, os
sys.path.insert(1, '../quantarhei')
sys.path.insert(2, '../spectre')
import quantarhei as qr
import spectre
import spectre.full as sef
import spectre.spectroscopy.abs_spectroscopy as abss

# %% [markdown]
# # (1.) Initial version - step 20

# %%
#path = 'C:/Users/micha/Documents/Studium/MScThesis/data-meta/E-scanopt-ether02-1mode/results_E-ether02-1mode-11010_scanopt_01_2023-07-01_14-14-11/'
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta/G-scanopt-ether02-1mode-free/results_G-ether02-1mode-free-P-11010_scanopt_01_2023-07-08_02-04-49"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(2, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\4220604495.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 1061.08955043
# Reorg: 21.2414109725
# System init: 6.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 8.02s
# Reorg: 1059.25858176
# Reorg: 21.4970613976
# System init: 5.86s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.81s
# Spectrum calculation (CPU): 7.93s
# Reorg: 1058.38635782
# Reorg: 21.755156481
# System init: 5.73s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.59s
# Spectrum calculation (CPU): 7.71s
# Reorg: 1055.82296436
# Reorg: 22.0155911192
# System init: 5.74s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.70s
# Spectrum calculation (CPU): 7.88s
# Reorg: 1054.14377813
# Reorg: 22.2772805891
# System init: 5.77s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 3.11s
# Spectrum calculation (CPU): 7.49s
# Reorg: 1032.88124437
# Reorg: 22.5420896477
# System init: 6.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.60s
# Spectrum calculation (CPU): 7.81s
# Reorg: 993.920200596
# Reorg: 22.8089568687
# System init: 5.66s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.60s
# Spectrum calculation (CPU): 7.93s
# Reorg: 955.201060549
# Reorg: 23.0777991727
# System init: 5.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 3.10s
# Spectrum calculation (CPU): 8.50s
# Reorg: 914.067453137
# Reorg: 23.348538091
# System init: 6.53s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.75s
# Spectrum calculation (CPU): 7.87s
# Reorg: 869.93544931
# Reorg: 23.6210994139
# System init: 5.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 8.05s
# Reorg: 824.332506989
# Reorg: 23.8954128735
# System init: 5.81s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.94s
# Spectrum calculation (CPU): 7.58s
# Reorg: 1039.31928128
# Reorg: 24.1714118594
# System init: 5.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.61s
# Spectrum calculation (CPU): 8.06s
# Reorg: 1051.91865605
# Reorg: 24.4490331574
# System init: 5.50s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.50s
# Spectrum calculation (CPU): 7.83s
# Reorg: 1063.80960775
# Reorg: 24.7282167149
# System init: 5.67s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 3.06s
# Spectrum calculation (CPU): 8.41s
# Reorg: 1037.86120111
# Reorg: 25.0089054282
# System init: 6.24s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.61s
# Spectrum calculation (CPU): 8.46s
# Reorg: 1007.51473705
# Reorg: 25.7391142064
# System init: 5.58s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.4s finished
# Tensor calculation: 2.72s
# Spectrum calculation (CPU): 8.62s
# Reorg: 1013.04755246
# Reorg: 247.20130821
# System init: 6.13s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 3.02s
# Spectrum calculation (CPU): 7.88s
# Reorg: 971.236312329
# Reorg: 295.088834176
# System init: 5.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 7.77s
# Reorg: 960.553316699
# Reorg: 415.752415167
# System init: 5.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.74s
# Spectrum calculation (CPU): 8.44s
# Reorg: 935.129905679
# Reorg: 582.905483196
# System init: 6.40s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 3.03s
# Spectrum calculation (CPU): 7.37s
# Reorg: 936.277134648
# Reorg: 761.245806687
# System init: 5.74s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.52s
# Spectrum calculation (CPU): 7.77s
# Reorg: 931.737225237
# Reorg: 992.969878553
# System init: 5.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.53s
# Spectrum calculation (CPU): 7.88s
# Reorg: 1072.07800099
# Reorg: 1193.44420021
# System init: 5.69s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.81s
# Spectrum calculation (CPU): 7.60s
# Reorg: 906.359974928
# Reorg: 1198.32455607
# System init: 5.66s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.67s
# Spectrum calculation (CPU): 7.65s
# Reorg: 877.745634227
# Reorg: 1171.94466423
# System init: 5.57s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\4220604495.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 7.77s

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(2, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        lab = f.split('.')[0].split('_')[2]
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [1500,1500], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [1500,1500], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(2, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'mode frequency (OM1) [cm$^{-1}$]')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering mode frequency (OM1) [cm$^{-1}$]}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\1259432313.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\1259432313.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 41/41 [00:09<00:00,  4.48it/s]
# 0.0529425726675
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])

ii = [i for i,x in enumerate(labels) if x == 1500][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

## omega
grid[3,1].plot(labels, om1, **pars)
grid[3,1].plot(labels[ii], om1[ii], **mpars)
grid[3,1].set_title('OM1')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    


grid[0,0].set_ylim(0,250)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.15)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

#grid[0,0].set_xlim(10, 80)
grid[0,2].set_ylim(0,20)

#plt.xlim(14000, 20000)
#plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

#sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
#cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(500))
    g.xaxis.set_major_formatter('{x:.0f}')
    g.xaxis.set_minor_locator(MultipleLocator(100))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('mode frequency (OM1) [cm$^{-1}$]')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\4009328405.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Text(0.5, 0, 'mode frequency (OM1) [cm$^{-1}$]')

# %% [markdown]
# # (2.) Finer step - step 5

# %%
#path = 'C:/Users/micha/Documents/Studium/MScThesis/data-meta/E-scanopt-ether02-1mode/results_E-ether02-1mode-11010_scanopt_01_2023-07-01_14-14-11/'
path = "C:/Users/micha/Documents/Studium/MScThesis/data-meta/G-scanopt-ether02-1mode-free/results_G-ether02-1mode-free-s5-P-11010_scanopt_01_2023-07-10_10-20-49"

# %%
files = [file for file in os.listdir(path) if file.endswith('.json') and file.startswith('opt')]
sfiles = sorted(files, key=lambda s: float(s.split('.')[0].split('_')[2]))

# %%
from matplotlib import cm
clm = cm.get_cmap('viridis', len(files))

fig, ax = plt.subplots(figsize=(6,7), dpi= 350)
labels = list()

for i, f in enumerate(sfiles[:]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    plt.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
    labels.append(lab)

plt.xlim(14000, 20000)
plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

abss.plot_ref(2, plot_to=ax, color='k', linestyle = 'dotted')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\4220604495.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Reorg: 1092.55889107
# Reorg: 21.2605766697
# System init: 5.76s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.60s
# Spectrum calculation (CPU): 8.12s
# Reorg: 1095.99321257
# Reorg: 21.3278617387
# System init: 5.67s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 7.91s
# Reorg: 1094.59760279
# Reorg: 21.3681222332
# System init: 5.57s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.88s
# Spectrum calculation (CPU): 7.30s
# Reorg: 1097.55219218
# Reorg: 21.4320535659
# System init: 5.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.73s
# Spectrum calculation (CPU): 7.85s
# Reorg: 1097.13258568
# Reorg: 21.496183733
# System init: 5.85s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.56s
# Spectrum calculation (CPU): 8.07s
# Reorg: 1098.29836518
# Reorg: 21.5604361096
# System init: 5.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.95s
# Spectrum calculation (CPU): 7.58s
# Reorg: 1097.27619996
# Reorg: 21.6248834858
# System init: 6.07s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 7.72s
# Reorg: 1096.59147913
# Reorg: 21.689450934
# System init: 5.85s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.55s
# Spectrum calculation (CPU): 7.87s
# Reorg: 1095.66304576
# Reorg: 21.7541951299
# System init: 5.84s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 7.70s
# Reorg: 1079.32074869
# Reorg: 21.8190862991
# System init: 5.85s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.66s
# Spectrum calculation (CPU): 7.74s
# Reorg: 1079.68553041
# Reorg: 21.8841212708
# System init: 5.48s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.53s
# Spectrum calculation (CPU): 7.94s
# Reorg: 1078.73384783
# Reorg: 21.9492982245
# System init: 5.30s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.94s
# Spectrum calculation (CPU): 7.40s
# Reorg: 1078.58046386
# Reorg: 22.0146177548
# System init: 6.00s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 7.71s
# Reorg: 1078.71082608
# Reorg: 22.0800772387
# System init: 5.76s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.48s
# Spectrum calculation (CPU): 7.96s
# Reorg: 1075.81621735
# Reorg: 22.1456751815
# System init: 5.52s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.63s
# Spectrum calculation (CPU): 8.07s
# Reorg: 1071.10156322
# Reorg: 22.2114101144
# System init: 5.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.50s
# Spectrum calculation (CPU): 7.81s
# Reorg: 1065.30693228
# Reorg: 22.2772805855
# System init: 5.63s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.55s
# Spectrum calculation (CPU): 7.90s
# Reorg: 1062.2322144
# Reorg: 22.3432851723
# System init: 5.45s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.74s
# Spectrum calculation (CPU): 7.71s
# Reorg: 1051.96860913
# Reorg: 22.4094224642
# System init: 5.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.40s
# Spectrum calculation (CPU): 7.56s
# Reorg: 1041.79207937
# Reorg: 22.475691078
# System init: 5.67s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.57s
# Spectrum calculation (CPU): 7.85s
# Reorg: 1032.88471337
# Reorg: 22.5420896477
# System init: 5.51s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.79s
# Spectrum calculation (CPU): 7.72s
# Reorg: 1022.76984042
# Reorg: 22.6086168279
# System init: 5.84s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.57s
# Spectrum calculation (CPU): 7.45s
# Reorg: 1011.7820208
# Reorg: 22.6752712929
# System init: 5.63s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 7.86s
# Reorg: 1002.92914362
# Reorg: 22.7420517371
# System init: 5.87s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 3.21s
# Spectrum calculation (CPU): 7.78s
# Reorg: 998.337713827
# Reorg: 22.8089568696
# System init: 6.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.98s
# Spectrum calculation (CPU): 8.42s
# Reorg: 986.837553841
# Reorg: 22.8759854218
# System init: 6.46s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 2.72s
# Spectrum calculation (CPU): 8.32s
# Reorg: 974.526230894
# Reorg: 22.9431361437
# System init: 6.05s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 3.19s
# Spectrum calculation (CPU): 8.05s
# Reorg: 952.045226716
# Reorg: 23.010407803
# System init: 6.14s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 3.17s
# Spectrum calculation (CPU): 7.81s
# Reorg: 955.461616815
# Reorg: 23.0777991727
# System init: 6.22s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.4s finished
# Tensor calculation: 2.78s
# Spectrum calculation (CPU): 8.62s
# Reorg: 944.895141783
# Reorg: 23.1453090637
# System init: 6.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.95s
# Spectrum calculation (CPU): 7.97s
# Reorg: 932.473797065
# Reorg: 23.2129362891
# System init: 6.18s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 3.02s
# Spectrum calculation (CPU): 7.77s
# Reorg: 920.896806243
# Reorg: 23.2806796828
# System init: 6.05s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 3.08s
# Spectrum calculation (CPU): 8.40s
# Reorg: 914.067637064
# Reorg: 23.348538091
# System init: 5.72s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 3.00s
# Spectrum calculation (CPU): 8.10s
# Reorg: 902.536794365
# Reorg: 23.4165103812
# System init: 6.60s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.91s
# Spectrum calculation (CPU): 7.98s
# Reorg: 880.770819406
# Reorg: 23.4845954364
# System init: 6.20s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.5s finished
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 8.68s
# Reorg: 876.069164293
# Reorg: 23.5527921407
# System init: 5.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.87s
# Spectrum calculation (CPU): 7.86s
# Reorg: 869.045398843
# Reorg: 23.6210994144
# System init: 6.02s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.89s
# Spectrum calculation (CPU): 7.68s
# Reorg: 862.682385359
# Reorg: 23.6895161783
# System init: 6.32s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 2.75s
# Spectrum calculation (CPU): 8.49s
# Reorg: 847.133176679
# Reorg: 23.7580413722
# System init: 6.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 3.06s
# Spectrum calculation (CPU): 8.28s
# Reorg: 836.165502984
# Reorg: 23.8266739485
# System init: 6.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.88s
# Spectrum calculation (CPU): 7.95s
# Reorg: 824.355787292
# Reorg: 23.8954128735
# System init: 6.33s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.75s
# Spectrum calculation (CPU): 8.40s
# Reorg: 818.791956643
# Reorg: 23.9642571274
# System init: 5.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 3.04s
# Spectrum calculation (CPU): 8.20s
# Reorg: 1014.19287067
# Reorg: 24.0332057033
# System init: 6.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 3.01s
# Spectrum calculation (CPU): 8.02s
# Reorg: 1029.05754777
# Reorg: 24.1022576116
# System init: 6.45s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 8.55s
# Reorg: 1030.83286983
# Reorg: 24.1714118594
# System init: 5.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 2.94s
# Spectrum calculation (CPU): 8.31s
# Reorg: 1047.12233178
# Reorg: 24.2406674907
# System init: 6.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.88s
# Spectrum calculation (CPU): 8.20s
# Reorg: 1037.17243061
# Reorg: 24.3100235441
# System init: 6.43s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.8s finished
# Tensor calculation: 2.95s
# Spectrum calculation (CPU): 9.04s
# Reorg: 1058.81617513
# Reorg: 24.3794790775
# System init: 6.74s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 8.47s
# Reorg: 1060.8227301
# Reorg: 24.4490331578
# System init: 6.46s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.88s
# Spectrum calculation (CPU): 8.08s
# Reorg: 1055.52856829
# Reorg: 24.5186848645
# System init: 6.43s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 3.12s
# Spectrum calculation (CPU): 8.47s
# Reorg: 1074.82263128
# Reorg: 24.5884332895
# System init: 6.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.75s
# Spectrum calculation (CPU): 7.92s
# Reorg: 1062.59829193
# Reorg: 24.6582775356
# System init: 6.39s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.69s
# Spectrum calculation (CPU): 8.04s
# Reorg: 1048.20743704
# Reorg: 24.7282167151
# System init: 6.13s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.87s
# Spectrum calculation (CPU): 8.22s
# Reorg: 1041.78591242
# Reorg: 24.7982499532
# System init: 6.52s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.4s finished
# Tensor calculation: 2.65s
# Spectrum calculation (CPU): 8.65s
# Reorg: 1047.81917263
# Reorg: 24.8683763854
# System init: 6.47s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.59s
# Spectrum calculation (CPU): 8.11s
# Reorg: 1051.88360626
# Reorg: 24.9385951573
# System init: 6.27s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.90s
# Spectrum calculation (CPU): 8.17s
# Reorg: 1038.62821736
# Reorg: 25.0089054251
# System init: 6.48s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 3.14s
# Spectrum calculation (CPU): 7.94s
# Reorg: 1035.14434773
# Reorg: 25.0793063563
# System init: 6.41s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.74s
# Spectrum calculation (CPU): 8.17s
# Reorg: 1032.22113056
# Reorg: 25.1497971251
# System init: 6.14s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.99s
# Spectrum calculation (CPU): 8.05s
# Reorg: 1023.72429215
# Reorg: 25.2203769189
# System init: 6.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 3.15s
# Spectrum calculation (CPU): 7.74s
# Reorg: 1014.23269968
# Reorg: 25.2910449341
# System init: 5.88s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 2.84s
# Spectrum calculation (CPU): 8.28s
# Reorg: 1007.32020974
# Reorg: 25.3618003756
# System init: 5.80s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 3.15s
# Spectrum calculation (CPU): 8.11s
# Reorg: 994.099837488
# Reorg: 25.432642459
# System init: 6.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.91s
# Spectrum calculation (CPU): 7.99s
# Reorg: 999.982832193
# Reorg: 75.1197681383
# System init: 6.18s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 2.78s
# Spectrum calculation (CPU): 8.36s
# Reorg: 1001.4949711
# Reorg: 143.078534866
# System init: 6.15s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 3.02s
# Spectrum calculation (CPU): 8.32s
# Reorg: 988.132758971
# Reorg: 143.397226627
# System init: 6.59s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.77s
# Spectrum calculation (CPU): 7.86s
# Reorg: 997.850776995
# Reorg: 181.147257028
# System init: 5.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 2.69s
# Spectrum calculation (CPU): 8.47s
# Reorg: 980.228348285
# Reorg: 170.527446977
# System init: 5.83s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 3.01s
# Spectrum calculation (CPU): 8.30s
# Reorg: 975.754907387
# Reorg: 235.89018291
# System init: 6.17s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.99s
# Spectrum calculation (CPU): 7.75s
# Reorg: 970.662687382
# Reorg: 277.900344142
# System init: 6.25s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.5s finished
# Tensor calculation: 2.95s
# Spectrum calculation (CPU): 8.71s
# Reorg: 958.151570612
# Reorg: 386.265751186
# System init: 5.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.5s finished
# Tensor calculation: 3.03s
# Spectrum calculation (CPU): 8.67s
# Reorg: 961.69800172
# Reorg: 387.69668683
# System init: 6.71s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.0s finished
# Tensor calculation: 2.76s
# Spectrum calculation (CPU): 8.22s
# Reorg: 961.515016984
# Reorg: 418.319137457
# System init: 6.26s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.7s finished
# Tensor calculation: 2.93s
# Spectrum calculation (CPU): 8.92s
# Reorg: 960.727261054
# Reorg: 435.145086224
# System init: 6.53s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 3.19s
# Spectrum calculation (CPU): 7.84s
# Reorg: 955.696299402
# Reorg: 483.888480124
# System init: 6.40s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.69s
# Spectrum calculation (CPU): 8.11s
# Reorg: 938.916191236
# Reorg: 515.2312352
# System init: 6.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 3.14s
# Spectrum calculation (CPU): 8.14s
# Reorg: 935.071699828
# Reorg: 581.105404716
# System init: 6.27s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.99s
# Spectrum calculation (CPU): 8.39s
# Reorg: 938.13735665
# Reorg: 662.10440181
# System init: 6.46s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.79s
# Spectrum calculation (CPU): 8.41s
# Reorg: 936.391947149
# Reorg: 669.796324796
# System init: 5.71s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 3.19s
# Spectrum calculation (CPU): 7.96s
# Reorg: 932.344657621
# Reorg: 703.63157421
# System init: 6.14s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.95s
# Spectrum calculation (CPU): 8.17s
# Reorg: 935.84174543
# Reorg: 758.717865852
# System init: 6.35s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 2.94s
# Spectrum calculation (CPU): 8.38s
# Reorg: 937.977130852
# Reorg: 841.213113216
# System init: 6.12s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.2s finished
# Tensor calculation: 3.25s
# Spectrum calculation (CPU): 8.42s
# Reorg: 948.914976668
# Reorg: 1067.29029621
# System init: 6.33s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 3.08s
# Spectrum calculation (CPU): 7.85s
# Reorg: 923.267926112
# Reorg: 1174.02575177
# System init: 6.21s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 7.93s
# Reorg: 913.508247277
# Reorg: 1183.25008406
# System init: 5.71s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.91s
# Spectrum calculation (CPU): 7.30s
# Reorg: 916.440361235
# Reorg: 1187.66895743
# System init: 5.82s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 7.98s
# Reorg: 922.17815354
# Reorg: 1191.57095659
# System init: 5.48s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.53s
# Spectrum calculation (CPU): 7.94s
# Reorg: 911.517158805
# Reorg: 1203.51361414
# System init: 5.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.98s
# Spectrum calculation (CPU): 7.46s
# Reorg: 901.995094632
# Reorg: 1203.20918343
# System init: 5.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.64s
# Spectrum calculation (CPU): 7.79s
# Reorg: 906.293163603
# Reorg: 1206.97273301
# System init: 5.66s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.60s
# Spectrum calculation (CPU): 7.80s
# Reorg: 908.34097687
# Reorg: 1217.14399524
# System init: 5.77s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.91s
# Spectrum calculation (CPU): 7.72s
# Reorg: 910.536622231
# Reorg: 1222.66537865
# System init: 5.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.61s
# Spectrum calculation (CPU): 7.65s
# Reorg: 894.633872761
# Reorg: 1187.61906748
# System init: 5.84s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.45s
# Spectrum calculation (CPU): 7.19s
# Reorg: 892.656521959
# Reorg: 1189.47708492
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.34s
# Spectrum calculation (CPU): 7.41s
# Reorg: 878.864459306
# Reorg: 1165.54479896
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.04s
# Reorg: 880.979620849
# Reorg: 1169.75050779
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.37s
# Reorg: 883.689756948
# Reorg: 1173.80022407
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.03s
# Reorg: 873.342294182
# Reorg: 1159.17364037
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.08s
# Reorg: 867.347222
# Reorg: 1152.67273438
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.26s
# Reorg: 861.839058033
# Reorg: 1147.31683358
# System init: 5.09s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.34s
# Spectrum calculation (CPU): 7.29s
# Reorg: 860.035291459
# Reorg: 1065.906671
# System init: 5.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.5s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 6.74s
# Reorg: 835.485677164
# Reorg: 1041.82174059
# System init: 5.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.32s
# Spectrum calculation (CPU): 7.96s
# Reorg: 841.625001885
# Reorg: 1133.00235735
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.21s
# Reorg: 841.97255029
# Reorg: 1137.88022913
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.13s
# Reorg: 843.300390311
# Reorg: 1146.66012783
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.8s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 6.97s
# Reorg: 857.666433376
# Reorg: 1240.25590214
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.37s
# Reorg: 859.370519732
# Reorg: 1247.98150661
# System init: 4.89s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.42s
# Reorg: 861.163489874
# Reorg: 1254.55207542
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 6.93s
# Reorg: 862.629603279
# Reorg: 1261.18349823
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.43s
# Reorg: 863.864924358
# Reorg: 1272.75612191
# System init: 5.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.67s
# Spectrum calculation (CPU): 7.32s
# Reorg: 867.067202037
# Reorg: 1280.47305609
# System init: 6.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.63s
# Spectrum calculation (CPU): 7.34s
# Reorg: 866.051292284
# Reorg: 1287.9398139
# System init: 6.18s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.42s
# Spectrum calculation (CPU): 7.81s
# Reorg: 868.507123268
# Reorg: 1292.119283
# System init: 6.32s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.44s
# Spectrum calculation (CPU): 7.35s
# Reorg: 883.294183962
# Reorg: 1313.53083102
# System init: 6.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.3s finished
# Tensor calculation: 2.67s
# Spectrum calculation (CPU): 8.55s
# Reorg: 885.936800568
# Reorg: 1316.05241594
# System init: 6.70s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.1s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 8.32s
# Reorg: 893.252421026
# Reorg: 1319.86378267
# System init: 6.49s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    8.4s finished
# Tensor calculation: 2.63s
# Spectrum calculation (CPU): 8.63s
# Reorg: 921.342153703
# Reorg: 1350.44778692
# System init: 6.52s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.62s
# Spectrum calculation (CPU): 7.74s
# Reorg: 921.568906261
# Reorg: 1355.46336244
# System init: 6.37s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.74s
# Spectrum calculation (CPU): 7.30s
# Reorg: 926.362448492
# Reorg: 1360.75185654
# System init: 6.31s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.59s
# Spectrum calculation (CPU): 7.59s
# Reorg: 937.426285856
# Reorg: 1366.4885766
# System init: 6.36s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.68s
# Spectrum calculation (CPU): 7.61s
# Reorg: 945.321107172
# Reorg: 1375.20700486
# System init: 6.22s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.52s
# Spectrum calculation (CPU): 7.70s
# Reorg: 950.736279179
# Reorg: 1377.01003833
# System init: 6.26s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.71s
# Spectrum calculation (CPU): 7.47s
# Reorg: 956.196203855
# Reorg: 1379.83043175
# System init: 6.75s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.57s
# Spectrum calculation (CPU): 7.96s
# Reorg: 963.516862178
# Reorg: 1382.68463291
# System init: 6.32s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.67s
# Spectrum calculation (CPU): 7.18s
# Reorg: 982.836342509
# Reorg: 1395.15519129
# System init: 5.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.52s
# Spectrum calculation (CPU): 7.27s
# Reorg: 985.875615738
# Reorg: 1399.69685357
# System init: 6.19s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.81s
# Spectrum calculation (CPU): 7.84s
# Reorg: 990.899739805
# Reorg: 1403.89488618
# System init: 5.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.70s
# Spectrum calculation (CPU): 7.81s
# Reorg: 1006.72624289
# Reorg: 1432.50175888
# System init: 5.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.69s
# Spectrum calculation (CPU): 7.80s
# Reorg: 1015.89243973
# Reorg: 1441.87807774
# System init: 6.15s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.65s
# Spectrum calculation (CPU): 7.71s
# Reorg: 1019.36375998
# Reorg: 1446.38924355
# System init: 6.22s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.60s
# Spectrum calculation (CPU): 7.65s
# Reorg: 1025.81519245
# Reorg: 1448.91626542
# System init: 5.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.63s
# Spectrum calculation (CPU): 7.69s
# Reorg: 1028.58683429
# Reorg: 1453.3090085
# System init: 6.18s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.61s
# Spectrum calculation (CPU): 7.66s
# Reorg: 937.486456008
# Reorg: 1457.99926712
# System init: 6.12s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.67s
# Spectrum calculation (CPU): 7.68s
# Reorg: 945.340359796
# Reorg: 1456.01946693
# System init: 6.03s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.63s
# Spectrum calculation (CPU): 7.60s
# Reorg: 954.269885199
# Reorg: 1457.90198118
# System init: 6.10s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.8s finished
# Tensor calculation: 2.75s
# Spectrum calculation (CPU): 8.00s
# Reorg: 962.746129501
# Reorg: 1457.13695274
# System init: 6.13s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.80s
# Spectrum calculation (CPU): 7.95s
# Reorg: 967.081768553
# Reorg: 1461.87929174
# System init: 6.04s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.66s
# Spectrum calculation (CPU): 7.69s
# Reorg: 976.761777412
# Reorg: 1453.54278075
# System init: 6.08s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.9s finished
# Tensor calculation: 2.69s
# Spectrum calculation (CPU): 8.08s
# Reorg: 982.483660687
# Reorg: 1455.08325862
# System init: 5.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.6s finished
# Tensor calculation: 2.66s
# Spectrum calculation (CPU): 7.86s
# Reorg: 985.001984736
# Reorg: 1457.95716885
# System init: 6.17s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.53s
# Spectrum calculation (CPU): 7.97s
# Reorg: 996.64188344
# Reorg: 1448.19759751
# System init: 5.69s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.66s
# Spectrum calculation (CPU): 7.75s
# Reorg: 1001.48389191
# Reorg: 1449.4548224
# System init: 5.90s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.65s
# Spectrum calculation (CPU): 7.62s
# Reorg: 1007.72429444
# Reorg: 1445.49004594
# System init: 4.98s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.2s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.43s
# Reorg: 1009.9420458
# Reorg: 1448.67417281
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.47s
# Reorg: 1020.23369353
# Reorg: 1459.41432269
# System init: 5.23s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 7.32s
# Reorg: 947.049581041
# Reorg: 1656.8416701
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.31s
# Reorg: 973.223234137
# Reorg: 1645.62710855
# System init: 4.91s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.31s
# Spectrum calculation (CPU): 7.50s
# Reorg: 969.760882263
# Reorg: 1693.45637682
# System init: 5.06s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.23s
# Reorg: 1009.79308587
# Reorg: 1616.05289737
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.5s finished
# Tensor calculation: 2.26s
# Spectrum calculation (CPU): 7.72s
# Reorg: 1012.40549405
# Reorg: 1620.72355986
# System init: 4.96s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.44s
# Spectrum calculation (CPU): 7.34s
# Reorg: 1015.01153859
# Reorg: 1625.38659678
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.7s finished
# Tensor calculation: 2.27s
# Spectrum calculation (CPU): 6.93s
# Reorg: 1017.79019355
# Reorg: 1630.04288514
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.36s
# Reorg: 1020.43120665
# Reorg: 1634.70906684
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.25s
# Spectrum calculation (CPU): 7.34s
# Reorg: 1023.44880825
# Reorg: 1639.38423976
# System init: 4.94s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.29s
# Reorg: 1026.10832444
# Reorg: 1644.03327353
# System init: 4.99s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.4s finished
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.64s
# Reorg: 1032.40929091
# Reorg: 1638.8153129
# System init: 4.92s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.7s finished
# Tensor calculation: 2.29s
# Spectrum calculation (CPU): 7.86s
# Reorg: 1047.87520111
# Reorg: 1637.86658668
# System init: 4.95s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.3s finished
# Tensor calculation: 2.30s
# Spectrum calculation (CPU): 7.58s
# Reorg: 1051.00036934
# Reorg: 1642.16205744
# System init: 4.97s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.1s finished
# Tensor calculation: 2.33s
# Spectrum calculation (CPU): 7.39s
# Reorg: 1083.53708058
# Reorg: 1633.77073102
# System init: 4.93s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.23s
# Spectrum calculation (CPU): 7.25s
# Reorg: 1107.26858607
# Reorg: 1608.03079954
# System init: 5.01s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    7.0s finished
# Tensor calculation: 2.28s
# Spectrum calculation (CPU): 7.26s
# Reorg: 1111.73925987
# Reorg: 1612.54007007
# System init: 5.04s
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    6.9s finished
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\4220604495.py:32: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm, orientation='horizontal')
# Tensor calculation: 2.24s
# Spectrum calculation (CPU): 7.14s

# %%
from matplotlib import cm
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
from matplotlib import gridspec

spline_s=0.0002
spline_k=3

clm = cm.get_cmap('viridis', len(files))

refdata = abss.plot_ref(2, return_data='data', plot=False)
refx, refy = refdata

fig, ax = plt.subplots(num=None, figsize=(7,6), dpi=350, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(nrows=2, ncols=3, width_ratios=(1, 0.05, 0.05), height_ratios=(0.6, 1), figure=fig) 
#ax3 = plt.subplot(gs[3])
ax0 = plt.subplot(gs[3])
ax1 = plt.subplot(gs[0], sharex = ax0)
ax4 = plt.subplot(gs[5])
ax2 = plt.subplot(gs[2])
plt.subplots_adjust(hspace=0, wspace=0)

####################
#   ax1   #  # ax2 #
####################
#   ax0   #  # ax4 #
####################

all_data_filename = 'all_data.npy'
all_data_path = os.path.join(path, all_data_filename)

if os.path.isfile(all_data_path) and True:
    x, y, zdata = np.load(all_data_path)[:,:-4]

    for i, z in enumerate(zdata):
        ax1.plot(x[i], z, linewidth=1.4, color=clm(i))
    
    zax = zdata - refy

else:
    labels = list()
    zax = None
    zdata = None
    i = 0

    for f in tqdm(sfiles[:]):
        i += 1
        filepath = os.path.join(path, f)
        optpars = spectre.utils.loadjson(filepath)
        datapath = filepath.replace('.json', '.npy')
        
        if os.path.isfile(datapath):
            data = np.load(datapath)
        else:
            syst, ta = spectre.full.init_system(optpars)
            spec = abss.calculate_abs_spectrum(syst, ta, optpars)
            spec.normalize()
            
            with qr.energy_units('1/cm'):
                data = np.vstack([spec.axis.data, spec.data])
                np.save(datapath, data)
    
        lab = f.split('.')[0].split('_')[2]
        spline = UnivariateSpline(*data, k=spline_k, s=spline_s)
        ydat = spline(refx) - refy
        
        if zax is None:
            zax = ydat
            zdata = spline(refx)
        else:
            zax = np.vstack([zax, ydat])
            zdata = np.vstack([zdata, spline(refx)])
        
        ax1.plot(data[0], data[1], label=lab, linewidth=1.4, color=clm(i))
        labels.append(float(lab))

    yax = np.array(labels)
    xax = refx
    x, y = np.meshgrid(xax, yax)
    np.save(all_data_path, np.array([x, y, zdata]))

maximum = np.abs(zax).max()
print(maximum)

cf = ax0.contourf(x, y, zax, 500, cmap="seismic", vmax=maximum, vmin=-maximum)

sm = plt.cm.ScalarMappable(cmap='seismic', norm=plt.Normalize(-maximum, maximum))
cbar = plt.colorbar(sm, cax=ax4, orientation='vertical')

sm2 = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(y[0,0], y[-1,0]))
cbar2 = plt.colorbar(sm2, cax=ax2, orientation='vertical')

ax0.plot([x[0,0], x[0,-1]], [1500,1500], linewidth=1, linestyle='dotted', c='w')
ax2.plot([0, 1], [1500,1500], linewidth=1, linestyle='dotted', c='w')

abss.plot_ref(2, plot_to=ax1, linestyle='dotted', c='k', linewidth=1.2)

from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in [ax0, ax1, ax2, ax4]:
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    g.tick_params(which='both', **pars)
    
    #g.xaxis.set_major_locator(MultipleLocator(20))
    #g.xaxis.set_major_formatter('{x:.0f}')
    #g.xaxis.set_minor_locator(MultipleLocator(10))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.xaxis.set_minor_locator(AutoMinorLocator(4))
    #g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    #g.get_yaxis().set_offset_position("left")
    #g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.097,0))

ax4.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax0.tick_params(which='both', labelbottom=True, labelleft=True)
ax1.tick_params(which='both', bottom=False)
ax2.tick_params(which='both', labelleft=False, labelright=True)
ax4.tick_params(which='both', labelleft=False, labelright=True)

ax0.set_xlim(x[0,0], x[0,-1])
ax0.set_ylim(y[0,0], y[-1,0])
ax1.set_ylim(-0.05, 1.05)

ax0.set_xlabel(r'frequency [cm$^{-1}$]')
ax0.set_ylabel(r'mode frequency (OM1) [cm$^{-1}$]')
ax1.set_ylabel(r'abs. [a.u.]')
ax2.set_ylabel(r'\parbox{40mm}{\centering mode frequency (OM1) [cm$^{-1}$]}')
ax4.set_ylabel(r'residuum')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\566128774.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\566128774.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax0 = plt.subplot(gs[3])
# 0.0278330274395
# Text(0, 0.5, 'residuum')

# %%
plt.plot((zax**2).sum(axis=1))

# %%
def draw_line(plot_to, xaxis, *vals, **pars):
    for val in vals:
        plot_to.plot([xaxis[0]-10, xaxis[-1]+10], [val, val], **pars)

# %%
from matplotlib import cm
from spectre.matplotlib_latex import plt_latex, format_ticks

plt_latex()
clm = cm.get_cmap('viridis', len(files))

fig, grid = plt.subplots(4, 3, figsize=(6,8), dpi=300, sharex=True, facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace=0.28, wspace=0.35)

labels = list()

tt11 = list()
tt12 = list()
dipyx = list()
ct11 = list()
ct12 = list()
ct = list()
lamb = list()
hr11 = list()
hr12 = list()
e1 = list()
de = list()
om1 = list()
alpha = list()

for i, f in enumerate(sfiles[:-4]):
    filepath = os.path.join(path, f)
    optpars = spectre.utils.loadjson(filepath)
    datapath = filepath.replace('.json', '.npy')
    
    if os.path.isfile(datapath):
        data = np.load(datapath)
    else:
        syst, ta = spectre.full.init_system(optpars)
        spec = abss.calculate_abs_spectrum(syst, ta, optpars)
        spec.normalize()
        
        with qr.energy_units('1/cm'):
            data = np.vstack([spec.axis.data, spec.data])
            np.save(datapath, data)

    lab = f.split('.')[0].split('_')[2]
    labels.append(float(lab))

    tt11.append(optpars['scaled_OB_CF_vib_11']['target_time'])
    tt12.append(optpars['scaled_OB_CF_vib_12']['target_time'])
    dipyx.append(4.5**2 / optpars['dipx'][0]**2)
    ct11.append(optpars['scaled_OB_CF_vib_11']['cortime'])
    ct12.append(optpars['scaled_OB_CF_vib_12']['cortime'])
    ct.append(optpars['spectral_density_el']['cortime'])
    lamb.append(optpars['spectral_density_el']['reorg'])
    hr11.append(optpars['hr1'][0])
    hr12.append(optpars['hr1'][1])
    e1.append(optpars['energies'][1])
    de.append(optpars['energies'][2] - optpars['energies'][1])
    om1.append(optpars['omega'][0])
    alpha.append(optpars['dia_alpha1'])

ii = [i for i,x in enumerate(labels) if x == 1500][0]

### Line & marker parameters
pars = dict(linewidth=2, )
mpars = dict(marker='+', c='r', markersize=7)
lpars = dict(linewidth=1, linestyle='dotted', c='k')


## TT11
grid[0,0].plot(labels, tt11, **pars)
grid[0,0].plot(labels[ii], tt11[ii], **mpars)
grid[0,0].set_title('VRT1')

## TT12
grid[0,1].plot(labels, tt12, **pars)
grid[0,1].plot(labels[ii], tt12[ii], **mpars)
grid[0,1].set_title('VRT2')
draw_line(grid[0,1], labels, 10, 300, **lpars)
          
## DIP Y/X
grid[0,2].plot(labels, dipyx, **pars)
grid[0,2].plot(labels[ii], dipyx[ii], **mpars)
grid[0,2].set_title('DIPY/X')
draw_line(grid[0,2], labels, 4.5**2 / 0.2**2, 4.5**2 / 2**2, **lpars)

## CT11
grid[1,0].plot(labels, ct11, **pars)
grid[1,0].plot(labels[ii], ct11[ii], **mpars)
grid[1,0].set_title('CT1')
draw_line(grid[1,0], labels, 10, 200, **lpars)

## CT12
grid[1,1].plot(labels, ct12, **pars)
grid[1,1].plot(labels[ii], ct12[ii], **mpars)
grid[1,1].set_title('CT2')
draw_line(grid[1,1], labels, 10, 200, **lpars)

## CT
grid[1,2].plot(labels, ct, **pars)
grid[1,2].plot(labels[ii], ct[ii], **mpars)
grid[1,2].set_title('CT')
draw_line(grid[1,2], labels, 10, 200, **lpars)

## HR11
grid[2,0].plot(labels, hr11, **pars)
grid[2,0].plot(labels[ii], hr11[ii], **mpars)
grid[2,0].set_title('HR1')
draw_line(grid[2,0], labels, 0.00001, 0.4, **lpars)

## HR12
grid[2,1].plot(labels, hr12, **pars)
grid[2,1].plot(labels[ii], hr12[ii], **mpars)
grid[2,1].set_title('HR2')
draw_line(grid[2,1], labels, 0.00001, 0.4, **lpars)

## lambda
grid[2,2].plot(labels, lamb, **pars)
grid[2,2].plot(labels[ii], lamb[ii], **mpars)
grid[2,2].set_title(r'$\lambda$')
draw_line(grid[2,2], labels, 10, 200, **lpars)

## e1
grid[3,0].plot(labels, e1, **pars)
grid[3,0].plot(labels[ii], e1[ii], **mpars)
grid[3,0].set_title('E1')
draw_line(grid[3,0], labels, 15000, 15800, **lpars)

## omega
grid[3,1].plot(labels, om1, **pars)
grid[3,1].plot(labels[ii], om1[ii], **mpars)
grid[3,1].set_title('OM1')
#draw_line(grid[3,1], labels, 0.00001, 0.4, **lpars)

# ## alpha
# grid[3,2].plot(labels, alpha, **pars)
# grid[3,2].plot(labels[ii], alpha[ii], **mpars)
# grid[3,2].set_title(r'$\alpha$')
# #draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)

## alpha
delta = (zax**2).sum(axis=1)
grid[3,2].plot(labels, delta, **pars)
grid[3,2].plot(labels[ii], delta[ii], **mpars)
grid[3,2].set_title(r'$\Delta^2$')
#draw_line(grid[3,2], labels, 0.00001, 0.4, **lpars)
    


grid[0,0].set_ylim(0,250)
grid[0,1].sharey(grid[0,0])
# grid[0,1].set_ylim(0,250)

#grid[1,0].set_ylim(0,100)
grid[1,1].sharey(grid[1,0])
grid[1,2].sharey(grid[1,0])
# grid[1,1].set_ylim(0,100)
# grid[1,2].set_ylim(0,100)

grid[2,0].set_ylim(-0.01, 0.15)
grid[2,1].sharey(grid[2,0])
# grid[2,1].set_ylim(-0.01, 0.075)

#grid[0,0].set_xlim(10, 80)
grid[0,2].set_ylim(0,20)

#plt.xlim(14000, 20000)
#plt.ylim(-0.1, 1.1)
#plt.legend(frameon=False)

#sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(labels[0], labels[-1]))
#cbar = plt.colorbar(sm, orientation='horizontal')
#cbar.set_ticklabels(labs)

### TICKS
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, MaxNLocator

for g in grid[:].flatten():
    pars = dict(labelbottom=False, labeltop=False, labelleft=True, labelright=False,
                bottom=True,           top=True,      left=True,      right=True,)
    #minor_pars = dict(bottom=True,           top=True,      left=True,      right=True)
    g.tick_params(which='both', **pars)
    #g.minor_tick_params(**minor_pars)
    
    g.xaxis.set_major_locator(MultipleLocator(400))
    g.xaxis.set_major_formatter('{x:.0f}')
    g.xaxis.set_minor_locator(MultipleLocator(100))
    g.yaxis.set_major_locator(MaxNLocator(nbins=4))
    g.yaxis.set_minor_locator(AutoMinorLocator(2))
    g.ticklabel_format(style='sci', axis='y', scilimits=(-1,3), useOffset=True)

    g.get_yaxis().set_offset_position("left")
    g.get_yaxis().OFFSETTEXTPAD = 7
    #g.get_yaxis().get_offset_text().set_position((-0.032,0))
    g.get_yaxis().get_offset_text().set_position((-0.097,0))

for g in grid[-1].flatten():
    pars = dict(labelbottom=True, labeltop=False, labelleft=True, labelright=False)
    g.tick_params(which='both', **pars)

# plt.locator_params(axis='x', nbins=4)
# plt.locator_params(axis='y', nbins=4)
#fig.tight_layout()

grid[3,1].set_xlabel('mode frequency (OM1) [cm$^{-1}$]')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_48008\2844271465.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   clm = cm.get_cmap('viridis', len(files))
# Text(0.5, 0, 'mode frequency (OM1) [cm$^{-1}$]')
